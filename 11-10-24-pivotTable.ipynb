# %%
import pandas as pd

# %%
snsdata=pd.read_csv("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\snsdata.csv")
snsdata.head(10)

# %%
insurance=pd.read_csv("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\insurance.csv")
insurance.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
cars=pd.read_csv("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\usedcars.csv")
cars.head()
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 4  2012    SE  17500     8367   White         AUTO

# %%
insurance.pivot_table(index='gender',values=['age','charges'])
# Out:
#               age       charges
# gender
# female  39.436090  12575.123638
# male    38.980684  13957.455827

# %%
cars.groupby(['model','color']).describe()['price']
# Out:
#               count          mean          std      min       25%      50%  \
# model color
# SE    Black    19.0  13345.210526  1735.349423   8495.0  12778.50  13950.0
#       Blue      9.0  13196.444444  1660.193596   9651.0  12995.00  13350.0
#       Gold      1.0  10955.000000          NaN  10955.0  10955.00  10955.0
#       Gray      7.0  12816.571429   925.406732  10955.0  12747.50  12992.0
#       Green     4.0  10900.000000  2928.402522   6980.0   9872.00  11314.0
#       Red      12.0  10829.083333  3538.446975   3800.0   9733.00  12130.0
#       Silver   11.0  11444.818182  2996.438346   6999.0   8997.50  10770.0
#       White    14.0  12459.071429  3159.846648   6995.0   9992.75  12747.5
#       Yellow    1.0   4899.000000          NaN   4899.0   4899.00   4899.0
# SEL   Black     4.0  15716.500000   951.668885  14990.0  14991.50  15440.5
#       Blue      3.0  16226.666667   686.758570  15688.0  15840.00  15992.0
# ...

# %%
cars.pivot_table(index='model',columns='color',values='price')
# Out:
# color         Black          Blue     Gold          Gray    Green  \
# model
# SE     13345.210526  13196.444444  10955.0  12816.571429  10900.0
# SEL    15716.500000  16226.666667      NaN  15592.600000  16950.0
# SES    12466.166667  13058.400000      NaN  12742.250000      NaN
#
# color           Red        Silver         White   Yellow
# model
# SE     10829.083333  11444.818182  12459.071429   4899.0
# SEL    13969.500000  16448.285714  15980.000000  21992.0
# SES    11689.272727  13905.714286   7900.000000   7999.0

# %%
cars.pivot_table(index='model',columns='color',values='price',aggfunc='count')
# Out:
# color  Black  Blue  Gold  Gray  Green   Red  Silver  White  Yellow
# model
# SE      19.0   9.0   1.0   7.0    4.0  12.0    11.0   14.0     1.0
# SEL      4.0   3.0   NaN   5.0    1.0   2.0     7.0    1.0     1.0
# SES     12.0   5.0   NaN   4.0    NaN  11.0    14.0    1.0     1.0

# %%
cars.pivot_table(index='model',columns='color',values='price',aggfunc='count',fill_value=0)#for NAN we can give count as zero
# Out:
# color  Black  Blue  Gold  Gray  Green  Red  Silver  White  Yellow
# model
# SE        19     9     1     7      4   12      11     14       1
# SEL        4     3     0     5      1    2       7      1       1
# SES       12     5     0     4      0   11      14      1       1

# %%
cars.pivot_table(index='model',columns='color',values='price',aggfunc='count',fill_value=0,margins=True)
# Out:
# color  Black  Blue  Gold  Gray  Green  Red  Silver  White  Yellow  All
# model
# SE        19     9     1     7      4   12      11     14       1   78
# SEL        4     3     0     5      1    2       7      1       1   24
# SES       12     5     0     4      0   11      14      1       1   48
# All       35    17     1    16      5   25      32     16       3  150

# %%
credit=pd.read_csv("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\credit.csv")
credit.head()
# Out:
#   checking_balance  months_loan_duration credit_history    purpose  amount  \
# 0           < 0 DM                     6       critical   radio/tv    1169
# 1       1 - 200 DM                    48         repaid   radio/tv    5951
# 2          unknown                    12       critical  education    2096
# 3           < 0 DM                    42         repaid  furniture    7882
# 4           < 0 DM                    24        delayed  car (new)    4870
#
#   savings_balance employment_length  installment_rate personal_status  \
# 0         unknown           > 7 yrs                 4     single male
# 1        < 100 DM         1 - 4 yrs                 2          female
# 2        < 100 DM         4 - 7 yrs                 2     single male
# 3        < 100 DM         4 - 7 yrs                 2     single male
# 4        < 100 DM         1 - 4 yrs                 3     single male
#
#   other_debtors  ...                  property age  installment_plan  \
# ...

# %%
credit.pivot_table(index=['purpose','personal_status'],values='amount')
# Out:
#                                            amount
# purpose             personal_status
# business            divorced male     4142.700000
#                     female            3195.421053
#                     married male      2323.444444
#                     single male       4750.491525
# car (new)           divorced male     2843.800000
#                     female            2531.557143
#                     married male      1632.050000
#                     single male       3570.597015
# car (used)          divorced male     6534.000000
#                     female            5814.375000
#                     married male      4743.333333
#                     single male       5221.800000
# domestic appliances divorced male     1338.000000
#                     female            1409.833333
#                     married male      1217.000000
#                     single male       1740.500000
# education           divorced male     2319.000000
# ...

# %%
credit.pivot_table(index='purpose',columns='personal_status',values='amount',fill_value=0)
# Out:
# personal_status      divorced male        female  married male  single male
# purpose
# business               4142.700000   3195.421053   2323.444444  4750.491525
# car (new)              2843.800000   2531.557143   1632.050000  3570.597015
# car (used)             6534.000000   5814.375000   4743.333333  5221.800000
# domestic appliances    1338.000000   1409.833333   1217.000000  1740.500000
# education              2319.000000   2187.809524   3711.000000  3964.666667
# furniture              3082.066667   2774.729730   2252.142857  3385.870588
# others                15857.000000  11653.666667      0.000000  5961.750000
# radio/tv               2138.142857   2400.517647   1920.976190  2718.157534
# repairs                7028.000000   2126.400000    875.333333  2725.333333
# retraining                0.000000   1757.666667    726.000000  1134.000000
