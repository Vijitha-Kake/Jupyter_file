# %%
import pandas as pd

# %%
df= pd.read_csv("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\IRIS.csv",header=None,
               names=["spetal len", 'sepal width', 'petal len','petal width','species'],
                converters={4:lambda s:s.split('-')[1]})

# %%
df.head()
# Out:
#    spetal len  sepal width  petal len  petal width species
# 0         5.1          3.5        1.4          0.2  setosa
# 1         4.9          3.0        1.4          0.2  setosa
# 2         4.7          3.2        1.3          0.2  setosa
# 3         4.6          3.1        1.5          0.2  setosa
# 4         5.0          3.6        1.4          0.2  setosa

# %%
#def converter(s):
 #   return s.split('-')[1]

# %%
cars=pd.read_csv("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\usedcars.csv",
                usecols=['price','color'])

# %%
cars.head()
# Out:
#    price   color
# 0  21992  Yellow
# 1  20995    Gray
# 2  19995  Silver
# 3  17809    Gray
# 4  17500   White

# %%
cars.ndim, cars.shape, cars.info(), cars.memory_usage()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   150 non-null    int64
#  1   color   150 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.5+ KB
# (2,
#  (150, 2),
#  None,
#  Index     128
#  price    1200
#  color    1200
#  dtype: int64)

# %%
excel=pd.read_excel("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\AdventureWorks2017.xlsx",
                   sheet_name=None)

# %%
excel
# Out:
# {'FactInternetSales':        ProductKey  OrderDateKey  DueDateKey  ShipDateKey  CustomerKey  \
#  0             310      20101229    20110110     20110105        21768
#  1             310      20101229    20110110     20110105        21768
#  2             346      20101229    20110110     20110105        28389
#  3             346      20101229    20110110     20110105        25863
#  4             336      20101229    20110110     20110105        14501
#  ...           ...           ...         ...          ...          ...
#  60394         485      20140128    20140209     20140204        15868
#  60395         225      20140128    20140209     20140204        15868
#  60396         485      20140128    20140209     20140204        18759
#  60397         486      20140128    20140209     20140204        18759
#  60398         225      20140128    20140209     20140204        18759
#
#         PromotionKey  CurrencyKey  SalesTerritoryKey SalesOrderNumber  \
# ...

# %%
excel.keys()
# Out:
# dict_keys(['FactInternetSales', 'DimProductCategory', 'DimProductSubcategory', 'DimDate', 'DimGeography', 'DimProduct'])

# %%
x=excel['DimProductSubcategory']
x
# Out:
#     ProductSubcategoryKey  ProductSubcategoryAlternateKey  \
# 0                       1                               1
# 1                       2                               2
# 2                       3                               3
# 3                       4                               4
# 4                       5                               5
# 5                       6                               6
# 6                       7                               7
# 7                       8                               8
# 8                       9                               9
# 9                      10                              10
# 10                     11                              11
# 11                     12                              12
# 12                     13                              13
# 13                     14                              14
# 14                     15                              15
# ...

# %%
fruits=pd.read_csv("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\fruits.csv")
fruits
# Out:
#               color  sphericity  weight   label
# 0            Orange       0.947     120  Orange
# 1            Orange       0.917     125  Orange
# 2            Orange       0.923     110  Orange
# 3            Orange       0.916     123  Orange
# 4            Orange       0.943     124  Orange
# 5            Orange       0.911     130  Orange
# 6            Orange       0.903     135  Orange
# 7            Orange       0.918     105  Orange
# 8            Orange       0.914     132  Orange
# 9            Orange       0.936     127  Orange
# 10  Greenish yellow       0.829     133  Orange
# 11  Greenish yellow       0.875     134  Orange
# 12  Greenish yellow       0.859     110  Orange
# 13            Green       0.849     119  Orange
# 14            Green       0.868     106  Orange
# 15  Greenish yellow       0.884     113  Orange
# 16  Greenish yellow       0.872     108  Orange
# 17  Greenish yellow       0.823     132  Orange
# 18            Green       0.853     119  Orange
# ...

# %%
fruits[:16]
# Out:
#               color  sphericity  weight   label
# 0            Orange       0.947     120  Orange
# 1            Orange       0.917     125  Orange
# 2            Orange       0.923     110  Orange
# 3            Orange       0.916     123  Orange
# 4            Orange       0.943     124  Orange
# 5            Orange       0.911     130  Orange
# 6            Orange       0.903     135  Orange
# 7            Orange       0.918     105  Orange
# 8            Orange       0.914     132  Orange
# 9            Orange       0.936     127  Orange
# 10  Greenish yellow       0.829     133  Orange
# 11  Greenish yellow       0.875     134  Orange
# 12  Greenish yellow       0.859     110  Orange
# 13            Green       0.849     119  Orange
# 14            Green       0.868     106  Orange
# 15  Greenish yellow       0.884     113  Orange

# %%
fruits[-16:]
# Out:
#              color  sphericity  weight  label
# 44             Red       0.727     169  Apple
# 45             Red       0.801     170  Apple
# 46  Reddish yellow       0.803     164  Apple
# 47             Red       0.845     154  Apple
# 48             Red       0.710     149  Apple
# 49  Reddish yellow       0.812     160  Apple
# 50             Red       0.784     142  Apple
# 51             Red       0.748     140  Apple
# 52             Red       0.723     165  Apple
# 53  Reddish yellow       0.815     152  Apple
# 54  Reddish yellow       0.823     167  Apple
# 55  Reddish yellow       0.745     172  Apple
# 56  Reddish yellow       0.753     143  Apple
# 57  Reddish yellow       0.753     177  Apple
# 58             Red       0.839     162  Apple
# 59  Reddish yellow       0.751     140  Apple

# %%
fruits[-16::2]
# Out:
#              color  sphericity  weight  label
# 44             Red       0.727     169  Apple
# 46  Reddish yellow       0.803     164  Apple
# 48             Red       0.710     149  Apple
# 50             Red       0.784     142  Apple
# 52             Red       0.723     165  Apple
# 54  Reddish yellow       0.823     167  Apple
# 56  Reddish yellow       0.753     143  Apple
# 58             Red       0.839     162  Apple

# %%
fruits[['label']]
# Out:
#      label
# 0   Orange
# 1   Orange
# 2   Orange
# 3   Orange
# 4   Orange
# 5   Orange
# 6   Orange
# 7   Orange
# 8   Orange
# 9   Orange
# 10  Orange
# 11  Orange
# 12  Orange
# 13  Orange
# 14  Orange
# 15  Orange
# 16  Orange
# 17  Orange
# 18  Orange
# 19  Orange
# 20  Orange
# 21  Orange
# 22  Orange
# 23  Orange
# 24  Orange
# 25  Orange
# 26  Orange
# 27  Orange
# 28  Orange
# 29  Orange
# 30   Apple
# 31   Apple
# 32   Apple
# 33   Apple
# 34   Apple
# 35   Apple
# 36   Apple
# 37   Apple
# 38   Apple
# 39   Apple
# 40   Apple
# 41   Apple
# 42   Apple
# 43   Apple
# 44   Apple
# 45   Apple
# 46   Apple
# 47   Apple
# 48   Apple
# 49   Apple
# 50   Apple
# 51   Apple
# 52   Apple
# 53   Apple
# 54   Apple
# 55   Apple
# 56   Apple
# 57   Apple
# 58   Apple
# 59   Apple

# %%
fruits[::4][['color','weight']]
# Out:
#               color  weight
# 0            Orange     120
# 4            Orange     124
# 8            Orange     132
# 12  Greenish yellow     110
# 16  Greenish yellow     108
# 20  Greenish yellow     101
# 24  Greenish yellow     145
# 28            Green     101
# 32            Green     164
# 36            Green     173
# 40   Reddish yellow     174
# 44              Red     169
# 48              Red     149
# 52              Red     165
# 56   Reddish yellow     143

# %%
cars=pd.read_csv("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\usedcars.csv",
                index_col='model')
cars.head()
# Out:
#        year  price  mileage   color transmission
# model
# SEL    2011  21992     7413  Yellow         AUTO
# SEL    2011  20995    10926    Gray         AUTO
# SEL    2011  19995     7351  Silver         AUTO
# SEL    2011  17809    11613    Gray         AUTO
# SE     2012  17500     8367   White         AUTO

# %%
cars=pd.read_csv("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\usedcars.csv")
cars.head(), id(cars), cars.index
# Out:
# (   year model  price  mileage   color transmission
#  0  2011   SEL  21992     7413  Yellow         AUTO
#  1  2011   SEL  20995    10926    Gray         AUTO
#  2  2011   SEL  19995     7351  Silver         AUTO
#  3  2011   SEL  17809    11613    Gray         AUTO
#  4  2012    SE  17500     8367   White         AUTO,
#  1481172933936,
#  RangeIndex(start=0, stop=150, step=1))

# %%
cars.set_index(keys='model',inplace=True)

# %%
id(cars)
# Out:
# 1481172933936

# %%
cars.head(),cars.index
# Out:
# (       year  price  mileage   color transmission
#  model
#  SEL    2011  21992     7413  Yellow         AUTO
#  SEL    2011  20995    10926    Gray         AUTO
#  SEL    2011  19995     7351  Silver         AUTO
#  SEL    2011  17809    11613    Gray         AUTO
#  SE     2012  17500     8367   White         AUTO,
#  Index(['SEL', 'SEL', 'SEL', 'SEL', 'SE', 'SEL', 'SEL', 'SEL', 'SES', 'SES',
#         ...
#         'SE', 'SE', 'SE', 'SES', 'SES', 'SES', 'SE', 'SE', 'SE', 'SE'],
#        dtype='object', name='model', length=150))

# %%
cars.reset_index(level='model',drop=True)
# Out:
#      year  price  mileage   color transmission
# 0    2011  21992     7413  Yellow         AUTO
# 1    2011  20995    10926    Gray         AUTO
# 2    2011  19995     7351  Silver         AUTO
# 3    2011  17809    11613    Gray         AUTO
# 4    2012  17500     8367   White         AUTO
# ..    ...    ...      ...     ...          ...
# 145  2006   6200    95000  Silver         AUTO
# 146  2002   5995    87003     Red         AUTO
# 147  2000   5980    96841     Red         AUTO
# 148  2001   4899   151479  Yellow         AUTO
# 149  2000   3800   109259     Red         AUTO
#
# [150 rows x 5 columns]

# %%
cars.reindex()
