# %%
import pandas as pd

# %%
excel=pd.read_excel("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\Dry_Bean_Dataset.xlsx")
excel #this data read only the 1st sheet
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
excel=pd.read_excel("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\AdventureWorks2017.xlsx",
                   sheet_name=1)
excel
# Out:
#    ProductCategoryKey  ProductCategoryAlternateKey ProductCategoryName
# 0                   1                            1               Bikes
# 1                   2                            2          Components
# 2                   3                            3            Clothing
# 3                   4                            4         Accessories

# %%
excel=pd.read_excel("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\AdventureWorks2017.xlsx",
                   sheet_name=[1,3])
excel
# Out:
# {1:    ProductCategoryKey  ProductCategoryAlternateKey ProductCategoryName
#  0                   1                            1               Bikes
#  1                   2                            2          Components
#  2                   3                            3            Clothing
#  3                   4                            4         Accessories,
#  3:        DateKey       Date  DayNumberOfWeek DayNameOfWeek  DayNumberOfMonth  \
#  0     20050101 2005-01-01                7      Saturday                 1
#  1     20050102 2005-01-02                1        Sunday                 2
#  2     20050103 2005-01-03                2        Monday                 3
#  3     20050104 2005-01-04                3       Tuesday                 4
#  4     20050105 2005-01-05                4     Wednesday                 5
#  ...        ...        ...              ...           ...               ...
# ...

# %%
type(excel)
# Out:
# dict

# %%
excel=pd.read_excel("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\AdventureWorks2017.xlsx",
                   sheet_name=None) #it read all sheets
excel #this will not consideer as dataframe instead it takes as dictionary
# Out:
# {'FactInternetSales':        ProductKey  OrderDateKey  DueDateKey  ShipDateKey  CustomerKey  \
#  0             310      20101229    20110110     20110105        21768
#  1             310      20101229    20110110     20110105        21768
#  2             346      20101229    20110110     20110105        28389
#  3             346      20101229    20110110     20110105        25863
#  4             336      20101229    20110110     20110105        14501
#  ...           ...           ...         ...          ...          ...
#  60394         485      20140128    20140209     20140204        15868
#  60395         225      20140128    20140209     20140204        15868
#  60396         485      20140128    20140209     20140204        18759
#  60397         486      20140128    20140209     20140204        18759
#  60398         225      20140128    20140209     20140204        18759
#
#         PromotionKey  CurrencyKey  SalesTerritoryKey SalesOrderNumber  \
# ...

# %%
type(excel)
# Out:
# dict

# %%
excel.keys()
# Out:
# dict_keys(['FactInternetSales', 'DimProductCategory', 'DimProductSubcategory', 'DimDate', 'DimGeography', 'DimProduct'])

# %%
df_DimProductCategory=excel['DimProductCategory']
df_DimProductCategory
# Out:
#    ProductCategoryKey  ProductCategoryAlternateKey ProductCategoryName
# 0                   1                            1               Bikes
# 1                   2                            2          Components
# 2                   3                            3            Clothing
# 3                   4                            4         Accessories

# %%
df_DimDate=excel['DimDate']
df_DimDate
# Out:
#        DateKey       Date  DayNumberOfWeek DayNameOfWeek  DayNumberOfMonth  \
# 0     20050101 2005-01-01                7      Saturday                 1
# 1     20050102 2005-01-02                1        Sunday                 2
# 2     20050103 2005-01-03                2        Monday                 3
# 3     20050104 2005-01-04                3       Tuesday                 4
# 4     20050105 2005-01-05                4     Wednesday                 5
# ...        ...        ...              ...           ...               ...
# 3647  20141227 2014-12-27                7      Saturday                27
# 3648  20141228 2014-12-28                1        Sunday                28
# 3649  20141229 2014-12-29                2        Monday                29
# 3650  20141230 2014-12-30                3       Tuesday                30
# 3651  20141231 2014-12-31                4     Wednesday                31
#
# ...

# %%
cars = pd.read_json("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\cars.json")
cars
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
fwf=pd.read_fwf("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\sample_fwf.csv"
               , header=None, widths=[4,4,4,2], names=['emp_no','emp_name','salary','dept_no'])
fwf
# Out:
#    emp_no emp_name  salary  dept_no
# 0    1001     abcd    2500       20
# 1    1002     wxyz    5000       30
# 2    1003     efgh    3000       10
