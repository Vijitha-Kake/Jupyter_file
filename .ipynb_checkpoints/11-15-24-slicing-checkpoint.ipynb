# %% [markdown]
# ## Subsetting the DataFrames (slicing)

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\fruits.csv")
df
# Out:
#               color  sphericity  weight   label
# 0            Orange       0.947     120  Orange
# 1            Orange       0.917     125  Orange
# 2            Orange       0.923     110  Orange
# 3            Orange       0.916     123  Orange
# 4            Orange       0.943     124  Orange
# 5            Orange       0.911     130  Orange
# 6            Orange       0.903     135  Orange
# 7            Orange       0.918     105  Orange
# 8            Orange       0.914     132  Orange
# 9            Orange       0.936     127  Orange
# 10  Greenish yellow       0.829     133  Orange
# 11  Greenish yellow       0.875     134  Orange
# 12  Greenish yellow       0.859     110  Orange
# 13            Green       0.849     119  Orange
# 14            Green       0.868     106  Orange
# 15  Greenish yellow       0.884     113  Orange
# 16  Greenish yellow       0.872     108  Orange
# 17  Greenish yellow       0.823     132  Orange
# 18            Green       0.853     119  Orange
# ...

# %%
df.shape
# Out:
# (60, 4)

# %%
df.head()
# Out:
#     color  sphericity  weight   label
# 0  Orange       0.947     120  Orange
# 1  Orange       0.917     125  Orange
# 2  Orange       0.923     110  Orange
# 3  Orange       0.916     123  Orange
# 4  Orange       0.943     124  Orange

# %%
df[:10]
# Out:
#     color  sphericity  weight   label
# 0  Orange       0.947     120  Orange
# 1  Orange       0.917     125  Orange
# 2  Orange       0.923     110  Orange
# 3  Orange       0.916     123  Orange
# 4  Orange       0.943     124  Orange
# 5  Orange       0.911     130  Orange
# 6  Orange       0.903     135  Orange
# 7  Orange       0.918     105  Orange
# 8  Orange       0.914     132  Orange
# 9  Orange       0.936     127  Orange

# %%
df[:10:2]
# Out:
#     color  sphericity  weight   label
# 0  Orange       0.947     120  Orange
# 2  Orange       0.923     110  Orange
# 4  Orange       0.943     124  Orange
# 6  Orange       0.903     135  Orange
# 8  Orange       0.914     132  Orange

# %%
df[-5:]
# Out:
#              color  sphericity  weight  label
# 55  Reddish yellow       0.745     172  Apple
# 56  Reddish yellow       0.753     143  Apple
# 57  Reddish yellow       0.753     177  Apple
# 58             Red       0.839     162  Apple
# 59  Reddish yellow       0.751     140  Apple

# %%
df[::-1]
# Out:
#               color  sphericity  weight   label
# 59   Reddish yellow       0.751     140   Apple
# 58              Red       0.839     162   Apple
# 57   Reddish yellow       0.753     177   Apple
# 56   Reddish yellow       0.753     143   Apple
# 55   Reddish yellow       0.745     172   Apple
# 54   Reddish yellow       0.823     167   Apple
# 53   Reddish yellow       0.815     152   Apple
# 52              Red       0.723     165   Apple
# 51              Red       0.748     140   Apple
# 50              Red       0.784     142   Apple
# 49   Reddish yellow       0.812     160   Apple
# 48              Red       0.710     149   Apple
# 47              Red       0.845     154   Apple
# 46   Reddish yellow       0.803     164   Apple
# 45              Red       0.801     170   Apple
# 44              Red       0.727     169   Apple
# 43              Red       0.821     158   Apple
# 42              Red       0.776     172   Apple
# 41   Reddish yellow       0.772     152   Apple
# ...

# %%
df[::5], df[::5].shape
# Out:
# (              color  sphericity  weight   label
#  0            Orange       0.947     120  Orange
#  5            Orange       0.911     130  Orange
#  10  Greenish yellow       0.829     133  Orange
#  15  Greenish yellow       0.884     113  Orange
#  20  Greenish yellow       0.838     101  Orange
#  25            Green       0.834     109  Orange
#  30            Green       0.717     154   Apple
#  35            Green       0.745     181   Apple
#  40   Reddish yellow       0.778     174   Apple
#  45              Red       0.801     170   Apple
#  50              Red       0.784     142   Apple
#  55   Reddish yellow       0.745     172   Apple,
#  (12, 4))

# %%
#indexing not allowed
df[10:11] #even for one row index not allowed instaed we ise slicing
# Out:
#               color  sphericity  weight   label
# 10  Greenish yellow       0.829     133  Orange

# %%
#columns
df['color']
# Out:
# 0              Orange
# 1              Orange
# 2              Orange
# 3              Orange
# 4              Orange
# 5              Orange
# 6              Orange
# 7              Orange
# 8              Orange
# 9              Orange
# 10    Greenish yellow
# 11    Greenish yellow
# 12    Greenish yellow
# 13              Green
# 14              Green
# 15    Greenish yellow
# 16    Greenish yellow
# 17    Greenish yellow
# 18              Green
# 19              Green
# 20    Greenish yellow
# 21    Greenish yellow
# 22              Green
# 23              Green
# 24    Greenish yellow
# 25              Green
# 26              Green
# 27              Green
# 28              Green
# 29    Greenish yellow
# 30              Green
# 31              Green
# 32              Green
# 33              Green
# 34              Green
# 35              Green
# 36              Green
# 37              Green
# 38              Green
# 39              Green
# 40     Reddish yellow
# ...

# %%
# the output comes as series as 1D & npo header
type(df['color']), df['color'].shape
# Out:
# (pandas.core.series.Series, (60,))

# %%
#to get the as a dataframe as 2D we give column names ina list 
df[['color']]
# Out:
#               color
# 0            Orange
# 1            Orange
# 2            Orange
# 3            Orange
# 4            Orange
# 5            Orange
# 6            Orange
# 7            Orange
# 8            Orange
# 9            Orange
# 10  Greenish yellow
# 11  Greenish yellow
# 12  Greenish yellow
# 13            Green
# 14            Green
# 15  Greenish yellow
# 16  Greenish yellow
# 17  Greenish yellow
# 18            Green
# 19            Green
# 20  Greenish yellow
# 21  Greenish yellow
# 22            Green
# 23            Green
# 24  Greenish yellow
# 25            Green
# 26            Green
# 27            Green
# 28            Green
# 29  Greenish yellow
# 30            Green
# 31            Green
# 32            Green
# 33            Green
# 34            Green
# 35            Green
# 36            Green
# 37            Green
# 38            Green
# 39            Green
# 40   Reddish yellow
# 41   Reddish yellow
# 42              Red
# 43              Red
# ...

# %%
type(df[['color']]), df[['color']].shape
# Out:
# (pandas.core.frame.DataFrame, (60, 1))

# %%
#by using list we can give multiple column names
df1=df[['color', 'label','weight']]
df1
# Out:
#               color   label  weight
# 0            Orange  Orange     120
# 1            Orange  Orange     125
# 2            Orange  Orange     110
# 3            Orange  Orange     123
# 4            Orange  Orange     124
# 5            Orange  Orange     130
# 6            Orange  Orange     135
# 7            Orange  Orange     105
# 8            Orange  Orange     132
# 9            Orange  Orange     127
# 10  Greenish yellow  Orange     133
# 11  Greenish yellow  Orange     134
# 12  Greenish yellow  Orange     110
# 13            Green  Orange     119
# 14            Green  Orange     106
# 15  Greenish yellow  Orange     113
# 16  Greenish yellow  Orange     108
# 17  Greenish yellow  Orange     132
# 18            Green  Orange     119
# 19            Green  Orange     143
# 20  Greenish yellow  Orange     101
# 21  Greenish yellow  Orange     149
# 22            Green  Orange     136
# 23            Green  Orange     141
# 24  Greenish yellow  Orange     145
# ...

# %%
df[:10][['color','weight']]
# Out:
#     color  weight
# 0  Orange     120
# 1  Orange     125
# 2  Orange     110
# 3  Orange     123
# 4  Orange     124
# 5  Orange     130
# 6  Orange     135
# 7  Orange     105
# 8  Orange     132
# 9  Orange     127

# %%
df[-10:][['color','label']]
# Out:
#              color  label
# 50             Red  Apple
# 51             Red  Apple
# 52             Red  Apple
# 53  Reddish yellow  Apple
# 54  Reddish yellow  Apple
# 55  Reddish yellow  Apple
# 56  Reddish yellow  Apple
# 57  Reddish yellow  Apple
# 58             Red  Apple
# 59  Reddish yellow  Apple

# %%
df.color, type(df.color)
# Out:
# (0              Orange
#  1              Orange
#  2              Orange
#  3              Orange
#  4              Orange
#  5              Orange
#  6              Orange
#  7              Orange
#  8              Orange
#  9              Orange
#  10    Greenish yellow
#  11    Greenish yellow
#  12    Greenish yellow
#  13              Green
#  14              Green
#  15    Greenish yellow
#  16    Greenish yellow
#  17    Greenish yellow
#  18              Green
#  19              Green
#  20    Greenish yellow
#  21    Greenish yellow
#  22              Green
#  23              Green
#  24    Greenish yellow
#  25              Green
#  26              Green
#  27              Green
#  28              Green
#  29    Greenish yellow
#  30              Green
#  31              Green
#  32              Green
#  33              Green
#  34              Green
#  35              Green
#  36              Green
#  37              Green
#  38              Green
#  39              Green
# ...

# %%
cars=pd.read_csv("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\usedcars.csv")
cars
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
cars[:14][['model','color','mileage']]
# Out:
#    model   color  mileage
# 0    SEL  Yellow     7413
# 1    SEL    Gray    10926
# 2    SEL  Silver     7351
# 3    SEL    Gray    11613
# 4     SE   White     8367
# 5    SEL  Silver    25125
# 6    SEL    Blue    27393
# 7    SEL  Silver    21026
# 8    SES  Silver    32655
# 9    SES  Silver    36116
# 10   SEL   Black    40539
# 11   SES  Silver     9199
# 12   SEL   Green     9388
# 13   SES     Red    32058

# %%
signals=pd.read_csv("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\Signals.csv")
signals
# Out:
#      id   sample   sign_type   r1   g1   b1   r2   g2   b2   r3  ...  b13  \
# 0     1    train  pedestrian  155  228  251  135  188  101  156  ...  244
# 1     2    train  pedestrian  142  217  242  166  204   44  142  ...  237
# 2     3    train  pedestrian   57   54   50  187  201   68   51  ...   59
# 3     4    train  pedestrian   22   35   41  171  178   26   19  ...   34
# 4     5    train  pedestrian  169  179  170  231  254   27   97  ...   91
# ..   ..      ...         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 201  67    train        stop   74   78   65  145   56   55  124  ...   65
# 202  68     test        stop  237  249  245  220   59   53  220  ...  154
# 203  69    train        stop  162  187  181  114   47   38  115  ...  209
# 204  70     test        stop  161  187  181   51   21   20   52  ...  166
# 205  99  example        stop  204  227  220  196   59   51  202  ...  196
#
#      r14  g14  b14  r15  g15  b15  r16  g16  b16
# ...

# %%
signals.sample(10) #randomly 10 sample will select
# Out:
#      id sample   sign_type   r1   g1   b1   r2   g2   b2   r3  ...  b13  r14  \
# 50   51  train  pedestrian  191  189  186  131   92   43   60  ...   30  173
# 12   13   test  pedestrian  221  244  237   52   45   26  205  ...   13   74
# 199  65  train        stop  130  155  155   65   30   29   65  ...   44   65
# 125  61  train       speed   67   78   73  148  178  172  148  ...   50  142
# 90   26  train       speed   29   44   43  140  162  154  122  ...  150  138
# 95   31  train       speed   36   51   51   68   90   90   66  ...   90   68
# 21   22   test  pedestrian  117  137  132  116  105   67   58  ...   22   18
# 189  55  train        stop  203  202  197  172   68   67  172  ...   83  165
# 38   39  train  pedestrian   52   58   45   37   60    4  209  ...   42   59
# 46   47   test  pedestrian  202  229  226  105  140   59  190  ...  121  157
#
#      g14  b14  r15  g15  b15  r16  g16  b16
# 50   115   29  173  115   29  180  120   35
# ...

# %%
signals.sample #conflict with the column name
# Out:
# <bound method NDFrame.sample of      id   sample   sign_type   r1   g1   b1   r2   g2   b2   r3  ...  b13  \
# 0     1    train  pedestrian  155  228  251  135  188  101  156  ...  244
# 1     2    train  pedestrian  142  217  242  166  204   44  142  ...  237
# 2     3    train  pedestrian   57   54   50  187  201   68   51  ...   59
# 3     4    train  pedestrian   22   35   41  171  178   26   19  ...   34
# 4     5    train  pedestrian  169  179  170  231  254   27   97  ...   91
# ..   ..      ...         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 201  67    train        stop   74   78   65  145   56   55  124  ...   65
# 202  68     test        stop  237  249  245  220   59   53  220  ...  154
# 203  69    train        stop  162  187  181  114   47   38  115  ...  209
# 204  70     test        stop  161  187  181   51   21   20   52  ...  166
# 205  99  example        stop  204  227  220  196   59   51  202  ...  196
#
#      r14  g14  b14  r15  g15  b15  r16  g16  b16
# ...

# %%
signals[['sample']]
# Out:
#       sample
# 0      train
# 1      train
# 2      train
# 3      train
# 4      train
# ..       ...
# 201    train
# 202     test
# 203    train
# 204     test
# 205  example
#
# [206 rows x 1 columns]
