# %%
import pandas as pd

# %%
cars=pd.read_csv("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\usedcars.csv")
cars
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
cars.ndim
# Out:
# 2

# %%
cars.shape
# Out:
# (150, 6)

# %%
cars.dtypes  #object means text type of datatype
# Out:
# year             int64
# model           object
# price            int64
# mileage          int64
# color           object
# transmission    object
# dtype: object

# %%
cars.head()
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 4  2012    SE  17500     8367   White         AUTO

# %%
cars.size
# Out:
# 900

# %%
cars.tail()
# Out:
#      year model  price  mileage   color transmission
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO

# %%
cars.head(15)
# Out:
#     year model  price  mileage   color transmission
# 0   2011   SEL  21992     7413  Yellow         AUTO
# 1   2011   SEL  20995    10926    Gray         AUTO
# 2   2011   SEL  19995     7351  Silver         AUTO
# 3   2011   SEL  17809    11613    Gray         AUTO
# 4   2012    SE  17500     8367   White         AUTO
# 5   2010   SEL  17495    25125  Silver         AUTO
# 6   2011   SEL  17000    27393    Blue         AUTO
# 7   2010   SEL  16995    21026  Silver         AUTO
# 8   2011   SES  16995    32655  Silver         AUTO
# 9   2010   SES  16995    36116  Silver         AUTO
# 10  2010   SEL  16995    40539   Black         AUTO
# 11  2011   SES  16992     9199  Silver         AUTO
# 12  2011   SEL  16950     9388   Green         AUTO
# 13  2010   SES  16950    32058     Red         AUTO
# 14  2011    SE  16000    15367   White         AUTO

# %%
cars.info() #method
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          150 non-null    int64
#  1   model         150 non-null    object
#  2   price         150 non-null    int64
#  3   mileage       150 non-null    int64
#  4   color         150 non-null    object
#  5   transmission  150 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 7.2+ KB

# %%
cars.memory_usage() #bytes of storage (percell 8bytes 8*150=1200)
# Out:
# Index            128
# year            1200
# model           1200
# price           1200
# mileage         1200
# color           1200
# transmission    1200
# dtype: int64

# %% [markdown]
# ## Atributes .shape, .dtype, .ndim, .size
# ## Methods .head(), .tail(), .memory_usage(), .info()
