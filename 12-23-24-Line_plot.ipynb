# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(['jan','feb','march','april','may','june'],[80,125,40,70,110,180],marker='o')
plt.show()

# %%
hdfc=pd.read_csv("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\HDFCBANK.csv")
icici=pd.read_csv("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\ICICIBANK.csv")
hdfc.head()
# Out:
#          Date    Symbol Series  Prev Close    Open    High     Low    Last  \
# 0  2000-01-03  HDFCBANK     EQ      157.40  166.00  170.00  166.00  170.00
# 1  2000-01-04  HDFCBANK     EQ      170.00  182.00  183.45  171.00  174.00
# 2  2000-01-05  HDFCBANK     EQ      173.80  170.00  173.90  165.00  168.00
# 3  2000-01-06  HDFCBANK     EQ      166.95  168.00  170.00  165.30  168.95
# 4  2000-01-07  HDFCBANK     EQ      168.30  162.15  171.00  162.15  170.75
#
#     Close    VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 0  170.00  169.52   33259  5.638122e+11     NaN                 NaN
# 1  173.80  174.99  168710  2.952261e+12     NaN                 NaN
# 2  166.95  169.20  159820  2.704094e+12     NaN                 NaN
# 3  168.30  168.44   85026  1.432166e+12     NaN                 NaN
# 4  168.35  166.79   85144  1.420158e+12     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
plt.plot('Open',data=hdfc,label="HDFC")
plt.plot('Open',data=icici,label='ICICI')
plt.legend()
plt.show()

# %%
stock=pd.read_csv("C:\\Users\\pgkvi\\OneDrive\\Desktop\\Python Practice\\DS course\\DataSet\\stock_px_2.csv")
stock.head()
# Out:
#             Unnamed: 0  AAPL   MSFT    XOM     SPX
# 0  2003-01-02 00:00:00  7.40  21.11  29.22  909.03
# 1  2003-01-03 00:00:00  7.45  21.14  29.24  908.59
# 2  2003-01-06 00:00:00  7.45  21.52  29.96  929.01
# 3  2003-01-07 00:00:00  7.43  21.93  28.95  922.93
# 4  2003-01-08 00:00:00  7.28  21.31  28.83  909.93

# %%
plt.plot('AAPL',data=stock,label='Apple')
plt.plot('MSFT',data=stock,label='Microsoft')
plt.legend()
plt.show()

# %%
[plt.plot(stock['Unnamed: 0'],SN,data=stock,label=SN)for SN in ['AAPL','MSFT','XOM','SPX']]
plt.legend()
plt.show()

# %%
for stock_name in ['AAPL','MSFT','XOM','SPX']:
    plt.plot(stock_name,data=stock,label=stock_name)
plt.legend()
plt.title('Stock price over a period of time')
plt.show()

# %%
#stock['Unnamed: 0'] = pd.to_datetime(stock['Unnamed: 0'])
[plt.plot(stock['Unnamed: 0'],stock_name, data=stock, label=stock_name) for stock_name in ['AAPL', 'MSFT', 'XOM', 'SPX']]

# Add labels, legend, and show the plot
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Prices Over Time')
plt.legend()
#plt.xticks(rotation=45)
plt.show()

# %%
stock.shape
# Out:
# (2214, 5)
